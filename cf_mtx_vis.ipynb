# %%
display_labels = ['Thought-terminatingcliché', 'Slogans', 'Reductioadhitlerum', 'CausalOversimplification', 'Obfuscation', 'Bandwagon', 'Exaggeration/Minimisation', 'Repetition', 'PresentingIrrelevantData(RedHerring)', 'Confusion', '"MisrepresentationofSomeonesPosition(StrawMan)"', 'Flag-waving', 'Doubt', 'Glitteringgeneralities(Virtue)', 'Appealtoauthority', 'Appealtofear/prejudice', 'LoadedLanguage', 'Intentionalvagueness', 'Whataboutism', 'Black-and-whiteFallacy/Dictatorship', 'Namecalling/Labeling', 'Smears']

# %%
import pandas as pd

RES_DIR = "linearregression_0212.csv"

df = pd.read_csv(RES_DIR)

cf_matrix_list = df["cf_mtx"][0].split(',')
cf_matrix_list = [cf_mtx.split(';') for cf_mtx in cf_matrix_list if cf_mtx != '']

df[["micro_f1","acc","prec","rec","model_name"]]
# Out:
#    micro_f1       acc      prec       rec        model_name
# 0  0.227898  0.192771  0.651685  0.138095  xlm-roberta-base

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

for cf_matrix in cf_matrix_list:
    mtx = np.array([[cf_matrix[1],cf_matrix[2]],[cf_matrix[3],cf_matrix[4]]]).astype(int)
    cfd = ConfusionMatrixDisplay(confusion_matrix=mtx)
    cfd.plot()
    cfd.ax_.set_title(cf_matrix[0])
