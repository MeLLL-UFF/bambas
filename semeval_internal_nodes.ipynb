# %%
hier = {
    "root": ["Logos", "Ethos", "Pathos"],
    "Logos": ["Repetition", "Obfuscation, Intentional vagueness, Confusion", "Reasoning", "Justification"],
    "Justification": [
        "Slogans",
        "Bandwagon",
        "Appeal to authority",
        "Flag-waving",
        "Appeal to fear/prejudice",
    ],
    "Reasoning": [
        "Simplification",
        "Distraction",
    ],
    "Simplification": [
        "Causal Oversimplification",
        "Black-and-white Fallacy/Dictatorship",
        "Thought-terminating cliché",
    ],
    "Distraction": [
        "Misrepresentation of Someone's Position (Straw Man)",
        "Presenting Irrelevant Data (Red Herring)",
        "Whataboutism",
    ],
    "Ethos": [
        "Appeal to authority",
        "Glittering generalities (Virtue)",
        "Bandwagon",
        "Ad Hominem",
        "Transfer",
    ],
    "Ad Hominem": [
        "Doubt",
        "Name calling/Labeling",
        "Smears",
        "Reductio ad hitlerum",
        "Whataboutism",
    ],
    "Pathos": [
        "Exaggeration/Minimisation",
        "Loaded Language",
        "Appeal to (Strong) Emotions",
        "Appeal to fear/prejudice",
        "Flag-waving",
        "Transfer",
    ]
}

def search_parents(label, hier=hier, parents=[]):
    parents = []
    if label=="root":return []
    for key in hier:
        value = hier[key]
        if key=="root":continue
        if label in value: 
            parents.append(key)
            parents.extend(search_parents(key, hier, parents))
    return parents

# %%
import pandas as pd

train = pd.read_json("dataset/semeval2024/subtask1/train.json")
train
# Out:
#          id                                               text  \
# 0     65635  THIS IS WHY YOU NEED\n\nA SHARPIE WITH YOU AT ...
# 1     67927  GOOD NEWS!\n\nNAZANIN ZAGHARI-RATCLIFFE AND AN...
# 2     68031                            PAING PHYO MIN IS FREE!
# 3     77490  Move your ships away!\n\noooook\n\nMove your s...
# 4     67641           WHEN YOU'RE THE FBI, THEY LET YOU DO IT.
# ...     ...                                                ...
# 6995  67360  If your doctor prescribes you medication witho...
# 6996  70579  DEFENDS TRUMP. \nMADE ALLEGATIONS OF ELECTION ...
# 6997  70305  I'm having trouble selling our incredibly enor...
# 6998  77769  I'm so happy we live in a world without slaver...
# 6999  67944  Reminder\nWomen's rights are human rights.\nAl...
#
#                                                  labels  \
# 0                [Black-and-white Fallacy/Dictatorship]
# 1     [Loaded Language, Glittering generalities (Vir...
# 2                                                    []
# 3                                                    []
# 4                          [Thought-terminating cliché]
# ...                                                 ...
# 6995  [Loaded Language, Causal Oversimplification, T...
# 6996                    [Loaded Language, Whataboutism]
# 6997                                                 []
# 6998                                                 []
# 6999                                          [Slogans]
#
#                                                    link
# 0     https://www.facebook.com/photo/?fbid=402355213...
# 1     https://www.facebook.com/amnesty/photos/531198...
# 2     https://www.facebook.com/amnesty/photos/427419...
# 3     https://www.facebook.com/rightpatriots/photos/...
# 4     https://www.facebook.com/AddictingInfoOrg/phot...
# ...                                                 ...
# 6995  https://www.facebook.com/TheControversia/photo...
# 6996  https://www.facebook.com/PatriotFetch/photos/p...
# 6997  https://www.facebook.com/PatriotFetch/photos/p...
# 6998  https://www.facebook.com/communism101/photos/5...
# 6999  https://www.facebook.com/amnesty/photos/509490...
#
# [7000 rows x 4 columns]

# %%
for idx, label_list in enumerate(train["labels"]):
    for label in label_list:
        parents = search_parents(label)
        if "Ad Hominem" in parents: label_list.append("Ad Hominem")
        if "Distraction" in parents: label_list.append("Distraction")
        if "Logos" in parents: label_list.append("Logos")
    train["labels"][idx] = label_list

train
# Out:
# /tmp/ipykernel_49035/3827239786.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["labels"][idx] = label_list
#          id                                               text  \
# 0     65635  THIS IS WHY YOU NEED\n\nA SHARPIE WITH YOU AT ...
# 1     67927  GOOD NEWS!\n\nNAZANIN ZAGHARI-RATCLIFFE AND AN...
# 2     68031                            PAING PHYO MIN IS FREE!
# 3     77490  Move your ships away!\n\noooook\n\nMove your s...
# 4     67641           WHEN YOU'RE THE FBI, THEY LET YOU DO IT.
# ...     ...                                                ...
# 6995  67360  If your doctor prescribes you medication witho...
# 6996  70579  DEFENDS TRUMP. \nMADE ALLEGATIONS OF ELECTION ...
# 6997  70305  I'm having trouble selling our incredibly enor...
# 6998  77769  I'm so happy we live in a world without slaver...
# 6999  67944  Reminder\nWomen's rights are human rights.\nAl...
#
#                                                  labels  \
# 0     [Black-and-white Fallacy/Dictatorship, Logos, ...
# 1     [Loaded Language, Glittering generalities (Vir...
# 2                                                    []
# 3                                                    []
# 4     [Thought-terminating cliché, Logos, Logos, Log...
# ...                                                 ...
# 6995  [Loaded Language, Causal Oversimplification, T...
# 6996  [Loaded Language, Whataboutism, Ad Hominem, Di...
# 6997                                                 []
# 6998                                                 []
# 6999                                   [Slogans, Logos]
#
#                                                    link
# 0     https://www.facebook.com/photo/?fbid=402355213...
# 1     https://www.facebook.com/amnesty/photos/531198...
# 2     https://www.facebook.com/amnesty/photos/427419...
# 3     https://www.facebook.com/rightpatriots/photos/...
# 4     https://www.facebook.com/AddictingInfoOrg/phot...
# ...                                                 ...
# 6995  https://www.facebook.com/TheControversia/photo...
# 6996  https://www.facebook.com/PatriotFetch/photos/p...
# 6997  https://www.facebook.com/PatriotFetch/photos/p...
# 6998  https://www.facebook.com/communism101/photos/5...
# 6999  https://www.facebook.com/amnesty/photos/509490...
#
# [7000 rows x 4 columns]

# %%
import os
import json
os.makedirs("dataset/semeval_internal", exist_ok=True)
train.to_json("dataset/semeval_internal/train.json", orient="records")
