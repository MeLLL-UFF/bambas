# %%
hier = {
    "root": ["Logos", "Ethos", "Pathos"],
    "Logos": ["Repetition", "Obfuscation, Intentional vagueness, Confusion", "Reasoning", "Justification"],
    "Justification": [
        "Slogans",
        "Bandwagon",
        "Appeal to authority",
        "Flag-waving",
        "Appeal to fear/prejudice",
    ],
    "Reasoning": [
        "Simplification",
        "Distraction",
    ],
    "Simplification": [
        "Causal Oversimplification",
        "Black-and-white Fallacy/Dictatorship",
        "Thought-terminating cliché",
    ],
    "Distraction": [
        "Misrepresentation of Someone's Position (Straw Man)",
        "Presenting Irrelevant Data (Red Herring)",
        "Whataboutism",
    ],
    "Ethos": [
        "Appeal to authority",
        "Glittering generalities (Virtue)",
        "Bandwagon",
        "Ad Hominem",
        "Transfer",
    ],
    "Ad Hominem": [
        "Doubt",
        "Name calling/Labeling",
        "Smears",
        "Reductio ad hitlerum",
        "Whataboutism",
    ],
    "Pathos": [
        "Exaggeration/Minimisation",
        "Loaded Language",
        "Appeal to (Strong) Emotions",
        "Appeal to fear/prejudice",
        "Flag-waving",
        "Transfer",
    ]
}

def search_parents(label, hier=hier, parents=[]):
    parents = []
    if label=="root":return []
    for key in hier:
        value = hier[key]
        if key=="root":continue
        if label in value: 
            parents.append(key)
            parents.extend(search_parents(key, hier, parents))
    return parents

# %%
import pandas as pd

train = pd.read_json("dataset/semeval2024/subtask1/dev_subtask1_en.json")

# %%
for idx, label_list in enumerate(train["labels"]):
    for label in label_list:
        parents = search_parents(label)
        if "Ad Hominem" in parents: label_list.append("Ad Hominem")
        if "Distraction" in parents: label_list.append("Distraction")
        if "Logos" in parents: label_list.append("Logos")
        # label_list.extend(parents)
    train["labels"][idx] = label_list
train
# Out:
# /tmp/ipykernel_33515/3654306931.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["labels"][idx] = label_list
#         id                                               text  \
# 0    63292  This is why we're free\n\nThis is why we're sa...
# 1    70419  IF YOU SAY WE'RE IN THE MIDDLE OF A DEADLY PAN...
# 2    63673  AFTER A YEAR OF ZERO EVIDENCE OF RUSSIAN COLLU...
# 3    71297                                      MY WAY MY WAY
# 4    66340  Putin signed a decree to exclude Lyman from Ru...
# ..     ...                                                ...
# 995  70426                                CATHING MEXICANS!!!
# 996  64176  \I WILL NEVER REGRET MY SUPPORT FOR PRESIDENT ...
# 997  68485  DEMAND KING SALMAN RELEASE CLERIC SHEIKH SALMA...
# 998  75006  \LISTEN TO MY ORDERS, EVIL PUPPET...\n\n... I ...
# 999  77886  DONALD J. TRUMP IS MY PRESIDENT!\n\nPLEASE LIK...
#
#                                                 labels  \
# 0                   [Causal Oversimplification, Logos]
# 1    [Loaded Language, Name calling/Labeling, Black...
# 2    [Smears, Misrepresentation of Someone's Positi...
# 3                                                   []
# 4                                    [Loaded Language]
# ..                                                 ...
# 995                                  [Loaded Language]
# 996  [Smears, Appeal to authority, Glittering gener...
# 997      [Black-and-white Fallacy/Dictatorship, Logos]
# 998  [Smears, Name calling/Labeling, Loaded Languag...
# 999                                   [Slogans, Logos]
#
#                                                   link
# 0    https://www.facebook.com/SilentmajorityDJT/pho...
# 1    https://www.facebook.com/PatriotFetch/photos/p...
# 2    https://www.facebook.com/www.russiatruth.co/ph...
# 3    https://www.facebook.com/photo/?fbid=850390752...
# 4    https://www.facebook.com/photo/?fbid=842540057...
# ..                                                 ...
# 995  https://www.facebook.com/GovLookout/photos/pb....
# 996  https://www.facebook.com/SilentmajorityDJT/pho...
# 997  https://www.facebook.com/amnesty/photos/367919...
# 998  https://www.facebook.com/photo/?fbid=234964353...
# 999  https://www.facebook.com/rightpatriots/photos/...
#
# [1000 rows x 4 columns]

# %%
for idx, label_list in enumerate(test["labels"]):
    for label in label_list:
        parents = search_parents(label)
        if "Ad Hominem" in parents: label_list.append("Ad Hominem")
        if "Distraction" in parents: label_list.append("Distraction")
        if "Logos" in parents: label_list.append("Logos")
        # label_list.extend(parents)
    train["labels"][idx] = label_list
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 for idx, label_list in enumerate(test["labels"]):
#       2     for label in label_list:
#       3         parents = search_parents(label)
#
# NameError: name 'test' is not defined

# %%
import os
import json
os.makedirs("dataset/semeval_internal", exist_ok=True)
train.to_json("dataset/semeval_internal/dev_internal.json", orient="records")
# test.to_json("dataset/semeval_internal/test_internal.json", orient="records")
